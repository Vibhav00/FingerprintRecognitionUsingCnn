# %% [markdown]
# GIVING UNIQUE CODES FOR THE ORIGINAL FINGERPRITS

# %%
import shutil

def copy_file(source_path, destination_path, new_filename):
    
    # Construct the destination path with the new filename
    new_file_path = f"{destination_path}/{new_filename}"

    # Copy the file to the destination with the new name
    shutil.copyfile(source_path, new_file_path)





import os
path = 'Real'
# path = 'Altered/Altered-Easy'
# path = 'Altered/Altered-Medium'
files = os.listdir(path)
print(files[0])
i=1

for index, file in enumerate(files):
    intialsplit=file.split('__')
    num=intialsplit[0]
    secondSplit=intialsplit[1].split('_')
    gender=secondSplit[0]
    hand=secondSplit[1]
    finger=secondSplit[2]
    if(int(num)<=50 and finger=="thumb" and hand=="Right"):
       copy_file(path+'/'+file,"DataProcessed","thumb"+gender+"."+num+"."+"0"+".BMP")
# Out:
# 100__M_Left_index_finger.BMP

# %% [markdown]
# GIVING UNIQUE CODES FOR THE EASY DISTORTED

# %%
import shutil

def copy_file(source_path, destination_path, new_filename):

    # Construct the destination path with the new filename
    new_file_path = f"{destination_path}/{new_filename}"

    # Copy the file to the destination with the new name
    shutil.copyfile(source_path, new_file_path)





import os
path = 'Altered/Altered-Easy'
# path = 'Altered/Altered-Medium'
files = os.listdir(path)
print(files[0])
i=1
folder = "DataProcessed"
for index, file in enumerate(files):
    intialsplit=file.split('__')
    num=intialsplit[0]
    secondSplit=intialsplit[1].split('_')
    gender=secondSplit[0]
    hand=secondSplit[1]
    finger=secondSplit[2]
    sit=secondSplit[4]

    print(sit)
    if(int(num)<=50 and finger=="thumb" and hand=="Right"):
        if(sit=="CR.BMP"):
          copy_file(path+'/'+file,folder,"thumb"+gender+"."+num+"."+"1"+".BMP")
        if(sit=="Obl.BMP"):
          copy_file(path+'/'+file,folder,"thumb"+gender+"."+num+"."+"2"+".BMP")
        if(sit=="Zcut.BMP"):
          copy_file(path+'/'+file,folder,"thumb"+gender+"."+num+"."+"3"+".BMP")
# Out:
# 100__M_Left_index_finger_CR.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# ...

# %% [markdown]
# GIVING UNIQUE CODES FOR THE  MEDIUM DISTORTED

# %%
import shutil

def copy_file(source_path, destination_path, new_filename):

    # Construct the destination path with the new filename
    new_file_path = f"{destination_path}/{new_filename}"

    # Copy the file to the destination with the new name
    shutil.copyfile(source_path, new_file_path)





import os
# path = 'Altered/Altered-Easy'
path = 'Altered/Altered-Medium'
files = os.listdir(path)
print(files[0])
i=1
folder = "DataProcessed"
for index, file in enumerate(files):
    intialsplit=file.split('__')
    num=intialsplit[0]
    secondSplit=intialsplit[1].split('_')
    gender=secondSplit[0]
    hand=secondSplit[1]
    finger=secondSplit[2]
    sit=secondSplit[4]

    print(sit)
    if(int(num)<=50 and finger=="thumb" and hand=="Right"):
        if(sit=="CR.BMP"):
          copy_file(path+'/'+file,folder,"thumb"+gender+"."+num+"."+"4"+".BMP")
        if(sit=="Obl.BMP"):
          copy_file(path+'/'+file,folder,"thumb"+gender+"."+num+"."+"5"+".BMP")
        if(sit=="Zcut.BMP"):
          copy_file(path+'/'+file,folder,"thumb"+gender+"."+num+"."+"6"+".BMP")
# Out:
# 100__M_Left_index_finger_CR.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# Obl.BMP
# Obl.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# ...

# %% [markdown]
# GIVING UNIQUE CODES FOR THE HARD DISTORTED

# %%
import shutil

def copy_file(source_path, destination_path, new_filename):

    # Construct the destination path with the new filename
    new_file_path = f"{destination_path}/{new_filename}"

    # Copy the file to the destination with the new name
    shutil.copyfile(source_path, new_file_path)





import os
# path = 'Altered/Altered-Easy'
# path = 'Altered/Altered-Medium'
path = 'Altered/Altered-Hard'
files = os.listdir(path)
print(files[0])
i=1
folder = "DataProcessed"
for index, file in enumerate(files):
    intialsplit=file.split('__')
    num=intialsplit[0]
    secondSplit=intialsplit[1].split('_')
    gender=secondSplit[0]
    hand=secondSplit[1]
    finger=secondSplit[2]
    sit=secondSplit[4]

    print(sit)
    if(int(num)<=50 and finger=="thumb" and hand=="Right"):
        if(sit=="CR.BMP"):
          copy_file(path+'/'+file,folder,"thumb"+gender+"."+num+"."+"7"+".BMP")
        if(sit=="Obl.BMP"):
          copy_file(path+'/'+file,folder,"thumb"+gender+"."+num+"."+"8"+".BMP")
        if(sit=="Zcut.BMP"):
          copy_file(path+'/'+file,folder,"thumb"+gender+"."+num+"."+"9"+".BMP")
# Out:
# 100__M_Left_index_finger_CR.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# Obl.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# Obl.BMP
# Obl.BMP
# CR.BMP
# Obl.BMP
# Obl.BMP
# Obl.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# Obl.BMP
# CR.BMP
# Obl.BMP
# Obl.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# CR.BMP
# Obl.BMP
# Zcut.BMP
# Obl.BMP
# ...
